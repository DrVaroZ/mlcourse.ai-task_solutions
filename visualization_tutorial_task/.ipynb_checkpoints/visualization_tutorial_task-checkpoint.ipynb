# %%
# Import all required modules
import pandas as pd
import numpy as np

# Disable warnings
import warnings
warnings.filterwarnings("ignore")

# Import plotting modules
import seaborn as sns
sns.set()
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.ticker
# %matplotlib inline

# %%
# Tune the visual settings for figures in `seaborn`
sns.set_context(
    "notebook", 
    font_scale=1.5,       
    rc={ 
        "figure.figsize": (11, 8), 
        "axes.titlesize": 18 
    }
)

from matplotlib import rcParams
rcParams['figure.figsize'] = 11, 8

# %%
DATA_PATH = "https://raw.githubusercontent.com/Yorko/mlcourse.ai/master/data/"
df = pd.read_csv(DATA_PATH + "mlbootcamp5_train.csv", sep=";")
print("Dataset size: ", df.shape)
df.head()
# Out:
# Dataset size:  (70000, 13)
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
# 3   3  17623       2     169    82.0    150    100            1     1      0
# 4   4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %%
df_uniques = pd.melt(
    frame=df,
    value_vars=["gender", "cholesterol", "gluc", "smoke", "alco", "active", "cardio"],
)
df_uniques = (
    pd.DataFrame(df_uniques.groupby(["variable", "value"])["value"].count())
    .sort_index(level=[0, 1])
    .rename(columns={"value": "count"})
    .reset_index()
)

sns.factorplot(
    x="variable", y="count", hue="value", data=df_uniques, kind="bar", size=12
);

# %%
df_uniques = pd.melt(
    frame=df,
    value_vars=["gender", "cholesterol", "gluc", "smoke", "alco", "active"],
    id_vars=["cardio"],
)
df_uniques = (
    pd.DataFrame(df_uniques.groupby(["variable", "value", "cardio"])["value"].count())
    .sort_index(level=[0, 1])
    .rename(columns={"value": "count"})
    .reset_index()
)

sns.factorplot(
    x="variable",
    y="count",
    hue="value",
    col="cardio",
    data=df_uniques,
    kind="bar",
    size=9,
);

# %%
for c in df.columns:
    n = df[c].nunique()
    print(c)
    if n <= 3:
        print(n, sorted(df[c].value_counts().to_dict().items()))
    else:
        print(n)
    print(10 * "-")
# Out:
# id
# 70000
# ----------
# age
# 8076
# ----------
# gender
# 2 [(1, 45530), (2, 24470)]
# ----------
# height
# 109
# ----------
# weight
# 287
# ----------
# ap_hi
# 153
# ----------
# ap_lo
# 157
# ----------
# cholesterol
# 3 [(1, 52385), (2, 9549), (3, 8066)]
# ----------
# gluc
# 3 [(1, 59479), (2, 5190), (3, 5331)]
# ----------
# smoke
# 2 [(0, 63831), (1, 6169)]
# ----------
# alco
# 2 [(0, 66236), (1, 3764)]
# ----------
# active
# 2 [(0, 13739), (1, 56261)]
# ----------
# cardio
# 2 [(0, 35021), (1, 34979)]
# ----------

# %%
df.describe()
# Out:
#                  id           age        gender        height        weight  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean   49972.419900  19468.865814      1.349571    164.359229     74.205690
# std    28851.302323   2467.251667      0.476838      8.210126     14.395757
# min        0.000000  10798.000000      1.000000     55.000000     10.000000
# 25%    25006.750000  17664.000000      1.000000    159.000000     65.000000
# 50%    50001.500000  19703.000000      1.000000    165.000000     72.000000
# 75%    74889.250000  21327.000000      2.000000    170.000000     82.000000
# max    99999.000000  23713.000000      2.000000    250.000000    200.000000
#
#               ap_hi         ap_lo   cholesterol          gluc         smoke  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean     128.817286     96.630414      1.366871      1.226457      0.088129
# ...

# %%
df.groupby(["gender"])["height"].describe(percentiles=[])
# Out:
#           count        mean       std   min    50%    max
# gender
# 1       45530.0  161.355612  7.052726  55.0  161.0  250.0
# 2       24470.0  169.947895  7.228895  65.0  170.0  207.0

# %% [markdown]
# 1 - women
# 2 - men

# %% [markdown]
# #  Task 1.2

# %%
pd.crosstab(df["gender"], df["alco"])
# Out:
# alco        0     1
# gender
# 1       44369  1161
# 2       21867  2603

# %% [markdown]
# #  Task1.3

# %%
pd.crosstab(df["gender"], df["smoke"], normalize='index')
# Out:
# smoke          0         1
# gender
# 1       0.982144  0.017856
# 2       0.781120  0.218880

# %% [markdown]
# # Task 1.4

# %%
df["age"] = df["age"].div(365)
df["age"] = df["age"].multiply(12)
df.groupby(["smoke"])["age"].agg([np.median])
# Out:
#            median
# smoke
# 0      648.394521
# 1      628.767123

# %% [markdown]
# # Task 1.5

# %%
df["age"] = df["age"].div(12).round(0)
df[((df["age"] >= 60.0) & (df["age"] <= 64)) & (df["cardio"] == 1) & (df["cholesterol"] == 1)]["id"].count()
# Out:
# 6338

# %% [markdown]
# Number of ill people, whose cholesterol is 1

# %%
df[((df["age"] >= 60.0) & (df["age"] <= 64)) & (df["cardio"] == 1) & (df["cholesterol"] == 3)]["id"].count()
# Out:
# 2342

# %% [markdown]
# Number of ill people, whose cholesterol is 3

# %% [markdown]
# # Task 1.6

# %%
bmi = (df["weight"] / (df["height"] / 100) ** 2)
df.insert(loc=len(df.columns), column="BMI", value=bmi)
df.head()
# Out:
#    id   age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  50.0       2     168    62.0    110     80            1     1      0
# 1   1  55.0       1     156    85.0    140     90            3     1      0
# 2   2  52.0       1     165    64.0    130     70            3     1      0
# 3   3  48.0       2     169    82.0    150    100            1     1      0
# 4   4  48.0       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio        BMI
# 0     0       1       0  21.967120
# 1     0       1       1  34.927679
# 2     0       0       1  23.507805
# 3     0       1       1  28.710479
# 4     0       0       0  23.011177

# %%
df["BMI"].median()
# Out:
# 26.374068120774975

# %%
df.groupby(["gender"])["BMI"].agg([np.mean])
# Out:
#              mean
# gender
# 1       27.987583
# 2       26.754442

# %%
df.groupby(["cardio"])["BMI"].agg([np.median])
# Out:
#            median
# cardio
# 0       25.476660
# 1       27.471384

# %%
df[(df["cardio"] == 0) & (df["alco"] == 0) & (df["gender"] == 2)]["BMI"].mean()
# Out:
# 25.872638075460173

# %%
df[(df["cardio"] == 0) & (df["alco"] == 0) & (df["gender"] == 1)]["BMI"].mean()
# Out:
# 26.845406594131518

# %% [markdown]
# # Task 1.7

# %%
df = df.drop(df[(df.ap_lo > df.ap_hi) |
          (df.height < df.height.quantile(q=0.025, interpolation='linear')) |
          (df.height > df.height.quantile(q=0.975, interpolation='linear')) |
          (df.weight < df.weight.quantile(q=0.025, interpolation='linear')) |
          (df.weight > df.weight.quantile(q=0.975, interpolation='linear'))].index)
df.describe()
#df = df.drop(df[(df.score < 50) & (df.score > 20)].index)
# Out:
#                  id           age        gender        height        weight  \
# count  63259.000000  63259.000000  63259.000000  63259.000000  63259.000000
# mean   49891.225770     53.334577      1.346591    164.490112     73.525384
# std    28834.472519      6.752607      0.475888      6.864083     11.914258
# min        0.000000     30.000000      1.000000    150.000000     51.000000
# 25%    24909.500000     48.000000      1.000000    160.000000     65.000000
# 50%    49887.000000     54.000000      1.000000    165.000000     72.000000
# 75%    74727.500000     58.000000      2.000000    169.000000     81.000000
# max    99999.000000     65.000000      2.000000    180.000000    108.000000
#
#               ap_hi         ap_lo   cholesterol          gluc         smoke  \
# count  63259.000000  63259.000000  63259.000000  63259.000000  63259.000000
# mean     128.851152     81.208239      1.358083      1.222245      0.086296
# ...

# %% [markdown]
# 9.63 % - percent of "dirty" data, which was dropped

# %% [markdown]
# # Task 2.1

# %%
# Drop non-numerical variables
numerical = list(
    set(
        [
            "gender",
            "cardio",
            "cholesterol",
            "smoke",
            "alco",
            "height",
            "weight"
        ]
    )
)

# Calculate and plot
corr_matrix = df[numerical].corr()
sns.heatmap(corr_matrix);

# %%
plt.figure(figsize=(8, 12))
heatmap = sns.heatmap(df.corr(method='pearson')[['gender']].sort_values(by='gender', ascending=False), vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Features Correlating with Gender', fontdict={'fontsize':18}, pad=16);

# %% [markdown]
# # Task 2.2

# %%
df1 = pd.melt(df.copy(), value_vars=['height'], id_vars='gender')
sns.violinplot(data=df1, x='variable', y='value', hue='gender', scale='area')
plt.show()

# %%
df2 = pd.DataFrame({
    'height' : df.height,
    'weight' : df.weight,
    'age' : df.age,
    'cholesterol' : df.cholesterol,
    'gluc' : df.gluc,
    'cardio' : df.cardio,
    'ap_hi' : df.ap_hi,
    'ap_lo' : df.ap_lo,
    'smoke' : df.smoke,
    'alco' : df.alco
})
corr = df2.corr(method = 'spearman')
sns.heatmap(corr, annot = True)
plt.show()

# %% [markdown]
# # Task 2.4

# %%
plt.figure(figsize=(25,14))
sns.countplot(x="age", hue="cardio", data=df);
plt.show()
